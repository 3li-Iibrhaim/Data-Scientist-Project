# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Data

# %%
df = pd.read_csv('Zini/financial-inclusion-in-afric/Train.csv')

# %%
td = pd.read_csv('Zini/financial-inclusion-in-afric/Test.csv')

# %%
variable = pd.read_csv('Zini/financial-inclusion-in-afric/VariableDefinitions.csv')

# %%
submitin = pd.read_csv('Zini/financial-inclusion-in-afric/SampleSubmission.csv')

# %% [markdown]
# ## Data Info

# %%
df.head()
# Out:
#   country  year    uniqueid bank_account location_type cellphone_access  \
# 0   Kenya  2018  uniqueid_1          Yes         Rural              Yes
# 1   Kenya  2018  uniqueid_2           No         Rural               No
# 2   Kenya  2018  uniqueid_3          Yes         Urban              Yes
# 3   Kenya  2018  uniqueid_4           No         Rural              Yes
# 4   Kenya  2018  uniqueid_5           No         Urban               No
#
#    household_size  age_of_respondent gender_of_respondent  \
# 0               3                 24               Female
# 1               5                 70               Female
# 2               5                 26                 Male
# 3               5                 34               Female
# 4               8                 26                 Male
#
#   relationship_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# 1      Head of Household                  Widowed
# ...

# %%
df.nunique()
# Out:
# country                      4
# year                         3
# uniqueid                  8735
# bank_account                 2
# location_type                2
# cellphone_access             2
# household_size              20
# age_of_respondent           85
# gender_of_respondent         2
# relationship_with_head       6
# marital_status               5
# education_level              6
# job_type                    10
# dtype: int64

# %%
df.describe()
# Out:
#                year  household_size  age_of_respondent
# count  23524.000000    23524.000000       23524.000000
# mean    2016.975939        3.797483          38.805220
# std        0.847371        2.227613          16.520569
# min     2016.000000        1.000000          16.000000
# 25%     2016.000000        2.000000          26.000000
# 50%     2017.000000        3.000000          35.000000
# 75%     2018.000000        5.000000          49.000000
# max     2018.000000       21.000000         100.000000

# %%
df.dtypes
# Out:
# country                   object
# year                       int64
# uniqueid                  object
# bank_account              object
# location_type             object
# cellphone_access          object
# household_size             int64
# age_of_respondent          int64
# gender_of_respondent      object
# relationship_with_head    object
# marital_status            object
# education_level           object
# job_type                  object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23524 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   bank_account            23524 non-null  object
#  4   location_type           23524 non-null  object
#  5   cellphone_access        23524 non-null  object
#  6   household_size          23524 non-null  int64
#  7   age_of_respondent       23524 non-null  int64
#  8   gender_of_respondent    23524 non-null  object
#  9   relationship_with_head  23524 non-null  object
#  10  marital_status          23524 non-null  object
#  11  education_level         23524 non-null  object
#  12  job_type                23524 non-null  object
# dtypes: int64(3), object(10)
# memory usage: 2.3+ MB

# %%
variable
# Out:
#       Variable Definitions                                         Unnamed: 1
# 0                  country                         Country interviewee is in.
# 1                     year                           Year survey was done in.
# 2                 uniqueid             Unique identifier for each interviewee
# 3            location_type                     Type of location: Rural, Urban
# 4         cellphone_access  If interviewee has access to a cellphone: Yes, No
# 5           household_size               Number of people living in one house
# 6        age_of_respondent                         The age of the interviewee
# 7     gender_of_respondent                Gender of interviewee: Male, Female
# 8   relationship_with_head  The interviewee’s relationship with the head o...
# 9           marital_status  The martial status of the interviewee: Married...
# 10         education_level  Highest level of education: No formal educatio...
# ...

# %% [markdown]
# ## EDA

# %%
sns.set_style("whitegrid");

# %%
sns.set()
sns.set_style("whitegrid")
sns.axes_style("whitegrid")
sns.set_style("ticks",
{"xtick.major.size":3,
"ytick.major.size":3})

# %%
sns.set_palette("husl",6,1)
sns.color_palette("Set1")
# sns.color_palette('blend')
# Out:
# [(0.8941176470588236, 0.10196078431372549, 0.10980392156862745),
#  (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),
#  (0.30196078431372547, 0.6862745098039216, 0.2901960784313726),
#  (0.596078431372549, 0.3058823529411765, 0.6392156862745098),
#  (1.0, 0.4980392156862745, 0.0),
#  (1.0, 1.0, 0.2),
#  (0.6509803921568628, 0.33725490196078434, 0.1568627450980392),
#  (0.9686274509803922, 0.5058823529411764, 0.7490196078431373),
#  (0.6, 0.6, 0.6)]

# %%
flatui = ["#9b59b6","#3498db","#95a5a6","#e74c3c","#34495e","#2ecc71"]

# %%
# sns.set_palette('Set1')
# sns.set_palette('Set2')
# sns.set_palette('Set3')
# sns.set_palette("pastel")
# sns.set_palette("husl", 9)
# sns.set_palette("Spectral")
# sns.set_palette("flare")

# %%
# plt.figure(figsize=[15,6])
sns.countplot(x="country",
data=df);

# %%
# plt.figure(figsize=[15,6])
sns.countplot(x="location_type",
data=df,
palette=flatui);

# %%
sns.set_palette('husl')

sns.countplot(x="bank_account",
data=df);

# %%
sns.set_palette("Set2");
sns.violinplot(y=df['gender_of_respondent'], x=df['age_of_respondent']);

# %%
sns.set_theme()

# %%
plt.figure(figsize=[15,6])
sns.histplot(df['age_of_respondent'],kde=True,color='r');

# %%
sns.set_palette("Set1");

# %%
plt.figure(figsize=[15,6])
sns.countplot(x=df[df['household_size']<15]['household_size']);

# %%
df['relationship_with_head'].value_counts()
# Out:
# Head of Household      12831
# Spouse                  6520
# Child                   2229
# Parent                  1086
# Other relative           668
# Other non-relatives      190
# Name: relationship_with_head, dtype: int64

# %%
sns.set_palette('Set1')  # change a color

# %%
plt.figure(figsize=[10,4])
sns.countplot(x="relationship_with_head",data=df);

# %%
sns.set_palette('husl')
df['marital_status'].unique()
# Out:
# array(['Married/Living together', 'Widowed', 'Single/Never Married',
#        'Divorced/Seperated', 'Dont know'], dtype=object)

# %%
plt.figure(figsize=[10,4])
sns.countplot(x=df['marital_status'], data=df);

# %%
plt.figure(figsize=[12,4]);
sns.countplot(x=df['education_level'], data=df, hue='country');

# %%
plt.figure(figsize=[15,4]);
sns.countplot(data=df, x="job_type")
# Out:
# <AxesSubplot:xlabel='job_type', ylabel='count'>

# %%
df.year.value_counts()
# Out:
# 2016    8735
# 2018    8169
# 2017    6620
# Name: year, dtype: int64

# %%
df[df.year==2017].country.value_counts()
# Out:
# Tanzania    6620
# Name: country, dtype: int64

# %%
sns.set_palette('Set2',9,1)

# %%
sns.catplot(data=df, x="country", y="year")

# %%
sns.catplot(
    data=df, y="country", hue="year", kind="count",
    palette="pastel", edgecolor=".6",
)

# %%
sns.countplot(x=df.cellphone_access,hue=df.country);

# %% [markdown]
# ## Tow Variable EDA

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()

# %%
le.fit(df['bank_account'])
# Out:
# LabelEncoder()

# %%
df['bank_account'] = le.transform(df['bank_account'])

# %%
df
# Out:
#       country  year       uniqueid  bank_account location_type  \
# 0       Kenya  2018     uniqueid_1             1         Rural
# 1       Kenya  2018     uniqueid_2             0         Rural
# 2       Kenya  2018     uniqueid_3             1         Urban
# 3       Kenya  2018     uniqueid_4             0         Rural
# 4       Kenya  2018     uniqueid_5             0         Urban
# ...       ...   ...            ...           ...           ...
# 23519  Uganda  2018  uniqueid_2113             0         Rural
# 23520  Uganda  2018  uniqueid_2114             0         Rural
# 23521  Uganda  2018  uniqueid_2115             0         Rural
# 23522  Uganda  2018  uniqueid_2116             0         Urban
# 23523  Uganda  2018  uniqueid_2117             0         Rural
#
#       cellphone_access  household_size  age_of_respondent  \
# 0                  Yes               3                 24
# 1                   No               5                 70
# ...

# %%
df['bank_account'].unique()
# Out:
# array([1, 0])

# %%
df['bank_account'].value_counts()
# Out:
# 0    20212
# 1     3312
# Name: bank_account, dtype: int64

# %%
have_bank = df[df['bank_account']==1].bank_account.value_counts()
not_have_bank = df[df['bank_account']==0].bank_account.value_counts()
all_bank = df['bank_account']
print((have_bank)/len(all_bank))
print((not_have_bank)/len(all_bank))

# not_have_bank/len(all_bank).to_bytes
# Out:
# 1    0.140792
# Name: bank_account, dtype: float64
# 0    0.859208
# Name: bank_account, dtype: float64

# %%
labels = [ 'Have Bank Account','Note Have a Bank Account']
sizes = [(have_bank)/len(all_bank),.85]
explode = (0, 0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
# Out:
# (-1.0576239071773084,
#  1.1498269217843506,
#  -1.2013373422532185,
#  1.1048255877263438)

# %% [markdown]
# `we should balanced this columns`

# %%
sns.barplot(x=df.cellphone_access, y = df['bank_account'],hue=df['country'])
# Out:
# <AxesSubplot:xlabel='cellphone_access', ylabel='bank_account'>

# %% [markdown]
#     we most look that keyia have the most cell phone than every country
#     also found most people have cell phone have bank account

# %%
sns.pointplot(x="location_type", 
y="bank_account", 
hue="country",
data=df,
);

# %% [markdown]
# ooh we can see all urban have a abank account than rural except in Tanzania

# %%
df.household_size.value_counts()
# Out:
# 2     5229
# 3     3920
# 4     3474
# 1     3057
# 5     2853
# 6     2096
# 7     1400
# 8      751
# 9      363
# 10     190
# 11      69
# 12      68
# 13      25
# 15      11
# 14      10
# 16       4
# 21       1
# 18       1
# 17       1
# 20       1
# Name: household_size, dtype: int64

# %%
plt.figure(figsize=[10,4])
sns.pointplot(x=df['household_size'],
y="bank_account",
hue="country",
#  col=''  ,           
data=df);

# %% [markdown]
# moste house size increase most bank account propaplity

# %% [markdown]
# ### Age

# %% [markdown]
# remomber we most slope the age to left

# %%
plt.figure(figsize=[10,4])
sns.histplot(df['age_of_respondent'].apply(np.square),kde=True,color='#22495e');

# %%
plt.figure(figsize=[10,4])
sns.histplot(df['age_of_respondent'].apply(np.sqrt),kde=True,color='g');

# %%
plt.figure(figsize=[10,4])
sns.histplot(df['age_of_respondent'].apply(np.squeeze),kde=True,color='#39ff14');

# %%
plt.figure(figsize=[10,4])
sns.histplot(df['age_of_respondent'].apply(np.log10),kde=True,color='#a900ff');

# %%
plt.figure(figsize=[10,4])
sns.histplot(df['age_of_respondent'].apply(np.log2),kde=True,color='#6aa6ff');

# %% [markdown]
# !!aaaa we see that apply log2,log10 give use more normal distrupution

# %%
# df.age_of_respondent = df['age_of_respondent'].apply(np.log2)

# %%
plt.figure(figsize=[15,5])
sns.barplot(x=df['age_of_respondent'],y=df.bank_account);

# %%
plt.figure(figsize=[10,4])
sns.pointplot(x=df['age_of_respondent'],y=df.bank_account,color='#77b5fe');

# %%
sns.barplot(x=df.gender_of_respondent,y=df.bank_account,palette=['#c74b0e','#3f4bd6']);

# %%
plt.figure(figsize=[10,4])
sns.pointplot(x=df.relationship_with_head,y=df.bank_account,color='#7fa092')
# Out:
# <AxesSubplot:xlabel='relationship_with_head', ylabel='bank_account'>

# %%
plt.figure(figsize=[10,4])
sns.barplot(x=df.relationship_with_head,y=df.bank_account)
# Out:
# <AxesSubplot:xlabel='relationship_with_head', ylabel='bank_account'>

# %% [markdown]
# The most of head of Household have a bank account and parent vice versa

# %%
plt.figure(figsize=[10,4])
sns.pointplot(x=df.marital_status,y=df.bank_account,hue=df.country)
# Out:
# <AxesSubplot:xlabel='marital_status', ylabel='bank_account'>

# %% [markdown]
# all feuture look like same except Dont' know

# %%
plt.figure(figsize=[10,4])
sns.barplot(x=df.marital_status,y=df.bank_account,hue=df.country)
# Out:
# <AxesSubplot:xlabel='marital_status', ylabel='bank_account'>

# %% [markdown]
#     😂 see we can delete it now
#     🤔 I think why D'nt Know
#     Please Drop this Feture now

# %%
plt.figure(figsize=[15,5]);
sns.barplot(x=df['education_level'], y=df.bank_account);

# %% [markdown]
# we can see No formal education allways have no bank account in vice versa Vocational

# %%
df.job_type.value_counts()
# Out:
# Self employed                   6437
# Informally employed             5597
# Farming and Fishing             5441
# Remittance Dependent            2527
# Other Income                    1080
# Formally employed Private       1055
# No Income                        627
# Formally employed Government     387
# Government Dependent             247
# Dont Know/Refuse to answer       126
# Name: job_type, dtype: int64

# %%
plt.figure(figsize=[12,10])
sns.barplot(y=df.job_type,x=df.bank_account);

# %% [markdown]
# we can see more poeple work in Formally employed Goverment have to be bank account rather than Infomally emplyee

# %% [markdown]
# ## Prepare Data to Model

# %% [markdown]
# #### 1 - Turn all data to label Data and save it in file

# %%
df.dtypes
# Out:
# country                   object
# year                       int64
# uniqueid                  object
# bank_account               int32
# location_type             object
# cellphone_access          object
# household_size             int64
# age_of_respondent          int64
# gender_of_respondent      object
# relationship_with_head    object
# marital_status            object
# education_level           object
# job_type                  object
# dtype: object

# %% [markdown]
# we can see there is object type we most convert it to catogary

# %%
df_object = ['country', 'location_type', 'cellphone_access','gender_of_respondent', 'relationship_with_head','marital_status','education_level','job_type']

# %%
for d in df_object:
    df[d] = df[d].astype('category')

# %%
for d in df_object:
    td[d] = td[d].astype('category')

# %%
df.dtypes
# Out:
# country                   category
# year                         int64
# uniqueid                    object
# bank_account                 int32
# location_type             category
# cellphone_access          category
# household_size               int64
# age_of_respondent            int64
# gender_of_respondent      category
# relationship_with_head    category
# marital_status            category
# education_level           category
# job_type                  category
# dtype: object

# %% [markdown]
# ##  `Label Encoding`

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
def label_encode(df):
    df = df.copy(deep=True)
#     data = df
    for i in df:
        if df[i].dtypes=='category':
            le.fit(df[i])     
#             le.classes_
            df[i] = le.transform(df[i])
    return df

# %%
train_label_encode = label_encode(df)
train_label_encode = train_label_encode.drop('uniqueid', axis=1)

# %%
test_label_encode = label_encode(td)
test_label_encode = test_label_encode.drop('uniqueid', axis=1)

# %%
test_label_encode.shape , train_label_encode.shape
# Out:
# ((10086, 11), (23524, 12))

# %%
train_label_encode.dtypes
# Out:
# country                   int32
# year                      int64
# bank_account              int32
# location_type             int32
# cellphone_access          int32
# household_size            int64
# age_of_respondent         int64
# gender_of_respondent      int32
# relationship_with_head    int32
# marital_status            int32
# education_level           int32
# job_type                  int32
# dtype: object

# %% [markdown]
# ## `one hote encoding`

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
enc = OneHotEncoder(handle_unknown='ignore')

# %%
def one_hot_encoder(df):
    data = pd.get_dummies(df, columns=df_object)
    return data

# %%
train_one_hote_encode = one_hot_encoder(df)
train_one_hote_encode = train_one_hote_encode.drop('uniqueid',axis=1)

# %%
test_one_hote_encode = one_hot_encoder(td)
test_one_hote_encode = test_one_hote_encode.drop('uniqueid',axis=1)

# %%
train_one_hote_encode.shape, test_one_hote_encode.shape
# Out:
# ((23524, 41), (10086, 40))

# %% [markdown]
# Splite Data to X, y

# %%
from sklearn.model_selection import train_test_split

# %%
Xl = train_label_encode.drop('bank_account',axis=1)
yl = train_label_encode['bank_account']

# %%
Xo = train_one_hote_encode.drop('bank_account',axis=1)
yo = train_one_hote_encode['bank_account']

# %% [markdown]
# ## Model the Data

# %%
##imported package cell
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import classification_report

# %%
 from sklearn.metrics import confusion_matrix

# %%
from sklearn.metrics import plot_confusion_matrix

# %%
from sklearn.metrics import RocCurveDisplay

# %%
from sklearn.metrics import plot_precision_recall_curve

# %% [markdown]
# `labe encode model`

# %%
X_train, X_test, y_train, y_test = train_test_split(
    Xl, yl, test_size=0.2, random_state=42)

# %%
X_train.shape , X_test.shape, y_train.shape, y_test.shape
# Out:
# ((18819, 11), (4705, 11), (18819,), (4705,))

# %% [markdown]
# `logistic Regression`

# %%
log = LogisticRegression(class_weight='balanced')

# %%
log.fit(X_train,y_train)
# Out:
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(class_weight='balanced')

# %%
log.score(X_test,y_test)
# Out:
# 0.748990435706695

# %%
y_pred = log.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.75      0.84      4063
#            1       0.32      0.75      0.45       642
#
#     accuracy                           0.75      4705
#    macro avg       0.64      0.75      0.64      4705
# weighted avg       0.86      0.75      0.78      4705

# %%
log_matrix = confusion_matrix(y_test, y_pred)
print(log_matrix)
# Out:
# [[3040 1023]
#  [ 158  484]]

# %%
plot_confusion_matrix(log, X_test, y_test,normalize='true');
# Out:
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
sns.heatmap(log_matrix/np.sum(log_matrix), annot=True, 
            fmt='.2%', cmap='Greens');

# %% [markdown]
# * `one hote encode`

# %%
# X_train_o, X_test_o, y_train_o, y_test_o = train_test_split(
#     Xo, yo, test_size=0.2, random_state=42)

# log_o = LogisticRegression(class_weight='balanced')

# log_o.fit(X_train_o,y_train_o)

# log_o.score(X_test_o,y_test_o)

# y_pred_o = log_o.predict(X_test_o)

# print(classification_report(y_test_o,y_pred_o))

# log_o_matrix = confusion_matrix(y_test_o, y_pred_o,normalize='true')
# print(log_o_matrix)

# plot_confusion_matrix(log_o, X_test_o, y_test_o,normalize='true');

# sns.heatmap(log_o_matrix/np.sum(log_o_matrix), annot=True, 
#             fmt='.2%', cmap='Blues');

# RocCurveDisplay.from_estimator(log, X_test, y_test)


# plot_precision_recall_curve(log, X_test, y_test)

# %% [markdown]
# oo we can see the model in oneHotEncoder same an labeEncodor , so we will use label encoder for the next

# %% [markdown]
# ### Sampling Data

# %%
sns.set_palette('husl')

sns.countplot(x="bank_account",
data=df,palette=['#c74b0e','#39ff14']);

# %%
y_train.value_counts().plot.pie(autopct = '%2f');

# %%
y_test
# Out:
# 6692     0
# 7628     0
# 10873    0
# 19704    0
# 7047     0
#         ..
# 14897    0
# 15292    0
# 5215     1
# 17487    0
# 19904    0
# Name: bank_account, Length: 4705, dtype: int32

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(random_state=42)

# %%
X_res, y_res = sm.fit_resample(X_train, y_train)

# %%
X_res_t , y_res_t =  sm.fit_resample(X_test, y_test)

# %%
sns.set_palette('Set1')

sns.countplot(x=y_res,
palette=['#f6cb1c','#ed8545']);

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((18819, 11), (18819,), (4705, 11), (4705,))

# %%
X_res.shape, y_res.shape, X_res_t.shape , y_test_t.shape
# Out:
# ((32298, 11), (32298,), (8126, 11), (8126,))

# %%
y_train.value_counts() ,  y_res.value_counts()
# Out:
# (0    16149
#  1     2670
#  Name: bank_account, dtype: int64,
#  0    16149
#  1    16149
#  Name: bank_account, dtype: int64)

# %% [markdown]
# how it look sampling now lets modiling

# %%
log_s = LogisticRegression()

# %%
log_s.fit(X_res,y_res)
# Out:
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
log_s.score(X_res_t, y_test_t)
# Out:
# 0.7527688899827714

# %%
y_pred_s = log_s.predict(X_res_t)

# %%
print(classification_report(y_test_t,y_pred_s))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.72      0.75      4063
#            1       0.74      0.78      0.76      4063
#
#     accuracy                           0.75      8126
#    macro avg       0.75      0.75      0.75      8126
# weighted avg       0.75      0.75      0.75      8126

# %% [markdown]
# ohh wandorfull

# %% [markdown]
# we gote good recall after resampling data

# %% [markdown]
# lets see confusing matrix

# %%
plot_confusion_matrix(log_s,X_res,y_res,normalize='true')
# Out:
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# let make up balanced

# %%
##Nice today Ali Now lets improve our model

# %% [markdown]
# `Note :` pefore imporve our model lets make predict and submition to zindi an see score\
#     remember: \
#     `0.130775332 and Rank 916`\
#     is socre for the first submitoin without any preprocessing

# %% [markdown]
# after preprocessing and submit i gote

# %%
X_res_t.shape
# Out:
# (8126, 11)

# %%
test_label_encode.shape
# Out:
# (10086, 11)

# %%
test_label_encode.head()
# Out:
#    country  year  location_type  cellphone_access  household_size  \
# 0        0  2018              1                 1               3
# 1        0  2018              1                 1               7
# 2        0  2018              0                 0               3
# 3        0  2018              0                 0               6
# 4        0  2018              1                 0               3
#
#    age_of_respondent  gender_of_respondent  relationship_with_head  \
# 0                 30                     1                       1
# 1                 51                     1                       1
# 2                 77                     0                       4
# 3                 39                     0                       1
# 4                 16                     1                       0
#
#    marital_status  education_level  job_type
# 0               2                3         2
# 1               2                5         3
# ...

# %%
X_res_t.head()
# Out:
#    country  year  location_type  cellphone_access  household_size  \
# 0        1  2016              0                 1               7
# 1        1  2016              0                 1               3
# 2        1  2016              1                 1               3
# 3        2  2017              1                 1               1
# 4        1  2016              0                 1               3
#
#    age_of_respondent  gender_of_respondent  relationship_with_head  \
# 0                 40                     1                       1
# 1                 24                     1                       0
# 2                 25                     0                       5
# 3                 35                     0                       1
# 4                 60                     1                       1
#
#    marital_status  education_level  job_type
# 0               2                0         5
# 1               3                3         1
# ...

# %%
pred = log_s.predict(test_label_encode)

# %%
submitin
# Out:
#                     unique_id  bank_account
# 0          uniqueid_1 x Kenya             0
# 1          uniqueid_2 x Kenya             0
# 2          uniqueid_3 x Kenya             0
# 3          uniqueid_4 x Kenya             0
# 4          uniqueid_5 x Kenya             0
# ...                       ...           ...
# 33605  uniqueid_2998 x Uganda             0
# 33606  uniqueid_2999 x Uganda             0
# 33607  uniqueid_3000 x Uganda             0
# 33608  uniqueid_3001 x Uganda             0
# 33609  uniqueid_3002 x Uganda             0
#
# [33610 rows x 2 columns]

# %%
test_label_encode
# Out:
#        country  year  location_type  cellphone_access  household_size  \
# 0            0  2018              1                 1               3
# 1            0  2018              1                 1               7
# 2            0  2018              0                 0               3
# 3            0  2018              0                 0               6
# 4            0  2018              1                 0               3
# ...        ...   ...            ...               ...             ...
# 10081        3  2018              0                 0               2
# 10082        3  2018              1                 1               8
# 10083        3  2018              1                 1               1
# 10084        3  2018              0                 1               6
# 10085        3  2018              1                 1               7
#
#        age_of_respondent  gender_of_respondent  relationship_with_head  \
# ...

# %%
td
# Out:
#       country  year       uniqueid location_type cellphone_access  \
# 0       Kenya  2018  uniqueid_6056         Urban              Yes
# 1       Kenya  2018  uniqueid_6060         Urban              Yes
# 2       Kenya  2018  uniqueid_6065         Rural               No
# 3       Kenya  2018  uniqueid_6072         Rural               No
# 4       Kenya  2018  uniqueid_6073         Urban               No
# ...       ...   ...            ...           ...              ...
# 10081  Uganda  2018  uniqueid_2998         Rural               No
# 10082  Uganda  2018  uniqueid_2999         Urban              Yes
# 10083  Uganda  2018  uniqueid_3000         Urban              Yes
# 10084  Uganda  2018  uniqueid_3001         Rural              Yes
# 10085  Uganda  2018  uniqueid_3002         Urban              Yes
#
#        household_size  age_of_respondent gender_of_respondent  \
# 0                   3                 30                 Male
# ...

# %%
df.dtypes
# Out:
# country                   category
# year                         int64
# uniqueid                    object
# bank_account                 int32
# location_type             category
# cellphone_access          category
# household_size               int64
# age_of_respondent            int64
# gender_of_respondent      category
# relationship_with_head    category
# marital_status            category
# education_level           category
# job_type                  category
# dtype: object

# %%
td.country
# Out:
# 0         Kenya
# 1         Kenya
# 2         Kenya
# 3         Kenya
# 4         Kenya
#           ...
# 10081    Uganda
# 10082    Uganda
# 10083    Uganda
# 10084    Uganda
# 10085    Uganda
# Name: country, Length: 10086, dtype: object

# %%
data = {'unique_id':td['uniqueid'] +' x ' + td['country'],
       'bank_account':pred}

# %%
second_submition = pd.DataFrame(data,index=None)

# %%
second_submition.to_csv('second_submition.csv',index=False)

# %%
## now lets make a submit in zindi and see what i will got

# %% [markdown]
#  Ohh tirable i gote :\
#  `0.283263930`\
#  what is wronge here lets see

# %% [markdown]
# aa i see that the predictio evaluatio was mean abslot errore and I note in this

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test_t,y_pred_s)
# Out:
# 0.24723111001722864

# %% [markdown]
# aaa letst imporve mean_absolute_errore

# %% [markdown]
# before imporve it lets read abbout it

# %% [markdown]
# aaa our model is very low accuracy lets check the wrong with data\
# first I will check ther wrong \
# second i will see the zero to mastery

# %% [markdown]
# **oo i found my problem in sampling**

# %% [markdown]
# lets do another sampling technique

# %% [markdown]
# ***`Under Sampler`***

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
rus = RandomUnderSampler(random_state=42)
X_res, y_res = rus.fit_resample(X_train, y_train)

# %%
X_res.shape , y_res.shape
# Out:
# ((5340, 11), (5340,))

# %%
X_res_t, y_res_t = rus.fit_resample(X_test, y_test)

# %%
X_res_t.shape, y_res_t.shape
# Out:
# ((1284, 11), (1284,))

# %%
y_res.value_counts()
# Out:
# 0    2670
# 1    2670
# Name: bank_account, dtype: int64

# %%
log = LogisticRegression()

# %%
log.fit(X_res,y_res)
# Out:
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
log.score(X_res_t,y_res_t)
# Out:
# 0.7429906542056075

# %%
y_preds = log.predict(X_res_t)

# %%
print(confusion_matrix(y_res_t,y_preds))
# Out:
# [[483 159]
#  [171 471]]

# %%
print(classification_report(y_res_t,y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.75      0.75       642
#            1       0.75      0.73      0.74       642
#
#     accuracy                           0.74      1284
#    macro avg       0.74      0.74      0.74      1284
# weighted avg       0.74      0.74      0.74      1284

# %%
plot_confusion_matrix(log,X_res_t,y_res_t,normalize='true')
# Out:
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
mean_absolute_error(y_res_t,y_preds)
# Out:
# 0.2570093457943925

# %% [markdown]
# hmmmm can't see any imporve think I can see??

# %% [markdown]
# lets see other technique or sampling data

# %% [markdown]
# `***Cross Validation***`

# %%
y_train.value_counts()
# Out:
# 0    16149
# 1     2670
# Name: bank_account, dtype: int64

# %%
from sklearn.model_selection import cross_val_score

# %%
log = LogisticRegression()

# %%
scores = cross_val_score(log, X_train, y_train, cv=5)
scores
# Out:
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
scores = cross_val_score(log, X_res, y_res, cv=5)
scores
# Out:
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.4, random_state=0)
# scaler = preprocessing.StandardScaler().fit(X_res)
# X_train_transformed = scaler.transform(X_res)

scaler = preprocessing.StandardScaler().fit(X_train)
X_train_transformed = scaler.transform(X_train)

# %%
log.fit(X_train_transformed,y_res)
# Out:
# LogisticRegression()

# %%
# X_test_transformed = scaler.transform(X_res_t)
scaler = preprocessing.StandardScaler().fit(X_test)
X_test_transformed = scaler.transform(X_test)

# %%
X_test_transformed.shape
# Out:
# (1284, 11)

# %%
log.score(X_test_transformed, y_res_t)
# Out:
# 0.7507788161993769

# %%
scores = cross_val_score(log, X_train_transformed, y_res, cv=5)
scores
# Out:
# array([0.74906367, 0.74625468, 0.73220974, 0.73689139, 0.76404494])

# %%
y_true = log.predict(X_train_transformed)

# %%
print(classification_report(y_true,y_res))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.75      0.74      2641
#            1       0.75      0.74      0.75      2699
#
#     accuracy                           0.75      5340
#    macro avg       0.75      0.75      0.75      5340
# weighted avg       0.75      0.75      0.75      5340

# %% [markdown]
# Hi **Ali** we test every sol but data note increase accurcy yet lets know do some thing else\
# lets Do some thing you know it:\
# `hyper parameter tuning`

# %% [markdown]
# ## befor go deep lets show what I learn
# * Manopilate Data
# * EDA
# * Logistic Regrision
# * some Statistic method
# * Endocing data `labe enocde` & `one hot encode`
# * Samping techique:
#     * smote
#     * up sampling
#     * down sampling
# * Cross Validation.

# %% [markdown]
# #  ***`Hyper parameter tuning 💡`***

# %% [markdown]
# I will use a `Logistic Regrisssion` hyper Parameter\
# <br>
# **1 - Most establish a baseline model\
# 2 - make a hyper parameter and compare it with a base line\
# 3 - choose the most hyper parameter with high accurecy.**

# %% [markdown]
# ## Precision:
#   **`Precision` is calculated by dividing the true positives by anything that was predicted as a positive.**
# ![precisio](https://miro.medium.com/max/720/1*yDuAOkdGvY4MC2Jp4VUl5Q.webp)

# %% [markdown]
# ## Recall
#
# **`Recall` : (`True Positive Rate`) is calculated by dividing the true positives by anything that should have been predicted as positive.**
# ![recall](https://miro.medium.com/max/720/1*8tyIfvFNXLE1egsfDj62QA.webp)

# %% [markdown]
# ## False Positive Rate
# ![false_postiv](https://miro.medium.com/max/720/1*9TVOYZ-zx4dTdgu8no7X4w.webp)

# %% [markdown]
# ## The ROC curve:
# ***is plotted with TPR against the FPR where TPR is on the y-axis and FPR is on the x-axis.***

# %% [markdown]
# ![ROC](https://miro.medium.com/max/640/1*pk05QGzoWhCgRiiFbz-oKQ.png)

# %% [markdown]
# **distinguish between positive class and negative class.**
# ![area under the curv](https://miro.medium.com/max/640/1*Uu-t4pOotRQFoyrfqEvIEg.png)
# ![area under the curv](https://miro.medium.com/max/640/1*HmVIhSKznoW8tFsCLeQjRw.png)
#
# ## overlap:
# **we introduce type 1 and type 2 errors. Depending upon the threshold, we can minimize or maximize them. When AUC is 0.7, it means there is a 70% chance that the model will be able to distinguish between positive class and negative class.**
# ![Roc](https://miro.medium.com/max/640/1*yF8hvKR9eNfqqej2JnVKzg.png)
# ![Roc](https://miro.medium.com/max/640/1*-tPXUvvNIZDbqXP0qqYNuQ.png)

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, auc,roc_curve

# %%
print('Accuracy of logistic regression classifier on train set: {:.2f}'.format(log.score(X_train, y_train)))
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(log.score(X_test, y_test)))
print('Precision of logistic regression classifier on test set: {:.2f}'.format(precision_score(y_test, y_pred)))
# Out:
# Accuracy of logistic regression classifier on train set: 0.14
# Accuracy of logistic regression classifier on test set: 0.14
# Precision of logistic regression classifier on test set: 0.32
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
clf = [
    LogisticRegression(solver='newton-cg',penalty='none',max_iter=1000),
    LogisticRegression(solver='lbfgs',penalty='none',max_iter=1000),
    LogisticRegression(solver='sag',penalty='none',max_iter=1000),
    LogisticRegression(solver='saga',penalty='none',max_iter=1000)
    ]
clf_columns = []
clf_compare = pd.DataFrame(columns = clf_columns)

row_index = 0
for alg in clf:
        
    predicted = alg.fit(X_train, y_train).predict(X_test)
    fp, tp, th = roc_curve(y_test, predicted)
    clf_name = alg.__class__.__name__
    clf_compare.loc[row_index, 'Train Accuracy'] = round(alg.score(X_train, y_train), 5)
    clf_compare.loc[row_index, 'Test Accuracy'] = round(alg.score(X_test, y_test), 5)
    clf_compare.loc[row_index, 'Precission'] = round(precision_score(y_test, predicted),5)
    clf_compare.loc[row_index, 'Recall'] = round(recall_score(y_test, predicted),5)
    clf_compare.loc[row_index, 'AUC'] = round(auc(fp, tp),5)

    row_index+=1
    
clf_compare.sort_values(by = ['Test Accuracy'], ascending = False, inplace = True)    
clf_compare
# Out:
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\scipy\optimize\linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\scipy\optimize\linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# ...

# %% [markdown]
# We can see the best `solver='lbfgs'`

# %% [markdown]
# note improve except `solver='lbfgs',penalty='l2'` imporve letel

# %%
clf = [
#     LogisticRegression(solver='newton-cg',penalty='l2',max_iter=1000),
    LogisticRegression(solver='lbfgs',penalty='l2',max_iter=1000),
#     LogisticRegression(solver='sag',penalty='l2',max_iter=1000),
#     LogisticRegression(solver='saga',penalty='l2',max_iter=1000),
    LogisticRegression(solver='lbfgs',penalty='none',max_iter=1000),
    LogisticRegression(solver='lbfgs',penalty='none',max_iter=1000,),
#     LogisticRegression(solver='lbfgs',penalty='l2',max_iter=500),
#     LogisticRegression(solver='lbfgs',penalty='l2',max_iter=1000,class_weight='balanced',multi_class='ovr',n_jobs=-1)
    ]
clf_columns = []
clf_compare = pd.DataFrame(columns = clf_columns)

row_index = 0
for alg in clf:
        
    predicted = alg.fit(X_train, y_train).predict(X_test)
    fp, tp, th = roc_curve(y_test, predicted)
    clf_name = alg.__class__.__name__
    clf_compare.loc[row_index, 'Train Accuracy'] = round(alg.score(X_train, y_train), 5)
    clf_compare.loc[row_index, 'Test Accuracy'] = round(alg.score(X_test, y_test), 5)
    clf_compare.loc[row_index, 'Precission'] = round(precision_score(y_test, predicted),5)
    clf_compare.loc[row_index, 'Recall'] = round(recall_score(y_test, predicted),5)
    clf_compare.loc[row_index, 'AUC'] = round(auc(fp, tp),5)

    row_index+=1
    
clf_compare.sort_values(by = ['Test Accuracy'], ascending = False, inplace = True)    
clf_compare
# Out:
#    Train Accuracy  Test Accuracy  Precission   Recall      AUC
# 1         0.87289        0.87906     0.66667  0.22741  0.60472
# 2         0.87289        0.87906     0.66667  0.22741  0.60472
# 0         0.87316        0.87885     0.66216  0.22897  0.60526

# %% [markdown]
# !Hyper Parameter Note imporve model will now lets do other technique

# %% [markdown]
# ohh other technique is `model selection`\
# I will use different model to imporve my accuracy\
# I learn auc and recall note important in much case\
# AUC and Recall And Precission is Important in `Industiry`\ and not Important in `Computiion`

# %% [markdown]
# ## ` Model Selection☺️`:

# %% [markdown]
# ## Lets Study Some Modle:
# **1- [Support Vector Machine](https://www.geeksforgeeks.org/support-vector-machine-algorithm) (SVM)\
# 2- [Naive Bayes Classifiers](https://www.geeksforgeeks.org/naive-bayes-classifiers)\
# 3- [K-Nearest Neighbours](https://www.geeksforgeeks.org/k-nearest-neighbours)\
# 4- [Decisio Tree](https://www.geeksforgeeks.org/decision-tree)**

# %% [markdown]
# ##  1 - SVM

# %% [markdown]
# ***the baseline model***

# %%
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
svm = SVC()

# %%
svm.fit(X_train, y_train)
# Out:
# SVC()

# %%
svm.fit(X_res,y_res)
# Out:
# SVC()

# %%
y_res.value_counts()
# Out:
# 0    16149
# 1    16149
# Name: bank_account, dtype: int64

# %%
svm.score(X_res_t,y_test_t)
# Out:
# 0.4790794979079498

# %%
svm.score(X_test,y_test)
# Out:
# 0.8635494155154091

# %%
clf = make_pipeline(StandardScaler(),
                    SVC(gamma='auto'))
clf.fit(X_train, y_train)
clf.score(X_test,y_test)
# Out:
# 0.8860786397449522

# %%
svm.fit(X_train, y_train)
svm.score(X_test,y_test)
# Out:
# 0.8635494155154091

# %%
plot_confusion_matrix(svm,X_test,y_test,cmap=)
# Out:
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
y_preds = svm.predict(X_test)

# %%
print(classification_report(y_test,y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93      4063
#            1       0.00      0.00      0.00       642
#
#     accuracy                           0.86      4705
#    macro avg       0.43      0.50      0.46      4705
# weighted avg       0.75      0.86      0.80      4705
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# ## SVM hyper parameter

# %% [markdown]
# ### First i fit to model affter scaling all data

# %% [markdown]
# * you should Scaled all Data

# %%
clf = [
    make_pipeline(StandardScaler(), SVC(gamma='auto')),
    make_pipeline(StandardScaler(), SVC(gamma='auto',kernel='sigmoid')),
#     make_pipeline(StandardScaler(), SVC(gamma='auto',kernel='precomputed')),
    make_pipeline(StandardScaler(), SVC(gamma='auto',kernel='poly')),
    make_pipeline(StandardScaler(), SVC(gamma='auto',kernel='linear')),
    make_pipeline(StandardScaler(), SVC(gamma='auto',C=0.001)),
    make_pipeline(StandardScaler(), SVC(gamma='auto',C=0.01)),
    make_pipeline(StandardScaler(), SVC(gamma='auto',C=0.03)),
    make_pipeline(StandardScaler(), SVC(gamma='auto',C=0.5)),
    make_pipeline(StandardScaler(), SVC(gamma='auto',max_iter=100))
    
    ]
clf_columns = []
clf_compare = pd.DataFrame(columns = clf_columns)

row_index = 0
for alg in clf:
        
    predicted = alg.fit(X_train, y_train).predict(X_test)
    fp, tp, th = roc_curve(y_test, predicted)
    clf_name = alg.__class__.__name__
    clf_compare.loc[row_index, 'Train Accuracy'] = round(alg.score(X_train, y_train), 5)
    clf_compare.loc[row_index, 'Test Accuracy'] = round(alg.score(X_test, y_test), 5)
    clf_compare.loc[row_index, 'Precission'] = round(precision_score(y_test, predicted),5)
    clf_compare.loc[row_index, 'Recall'] = round(recall_score(y_test, predicted),5)
    clf_compare.loc[row_index, 'AUC'] = round(auc(fp, tp),5)

    row_index+=1
    
clf_compare.sort_values(by = ['Test Accuracy'], ascending = False, inplace = True)    
clf_compare
# Out:
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
svm = make_pipeline(StandardScaler(), SVC(gamma='auto'))

# %%
svm.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(gamma='auto'))])

# %%
svm.score(X_train,y_train)
# Out:
# 0.8828843190392688

# %%
pred = svm.predict(X_test)

# %%
mean_absolute_error(y_test,pred)
# Out:
# 0.11392136025504782

# %%
mean_absolute_error(y_train,svm.predict(X_train))
# Out:
# 0.11711568096073117

# %% [markdown]
# ## 2- Naive Bayes Classifiers

# %% [markdown]
# #### 2.1- Gaussian Naive Bayes
# #### 2.2- Complement Naive Bayes
# #### 2.3 -Bernoulli Naive Bayes
# #### 2.4 -Multinomial Naive Bayes

# %% [markdown]
# ###  `Gaussian Naive Bayes`

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
gnb.score(X_test,y_test)
# Out:
# 0.8403825717321998

# %%
y_pred = gnb.fit(X_train, y_train).predict(X_test)
print("Number of mislabeled points out of a total %d points : %d"
      % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 4705 points : 751

# %% [markdown]
# ### `Multinomial Naive Bayes`

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
mnb = MultinomialNB()
mnb.fit(X_train, y_train)
mnb.score(X_test, y_test)
# Out:
# 0.8656748140276301

# %%
mean_absolute_error(y_train,mnb.predict(X_train)) ,mean_absolute_error(y_test,mnb.predict(X_test))
# Out:
# (0.13799883096870186, 0.1343251859723698)

# %% [markdown]
# ### `Complement Naive Bayes`

# %%
from sklearn.naive_bayes import ComplementNB

# %%
cnb = ComplementNB()
cnb.fit(X_train, y_train)
cnb.score(X_test,y_test)
# Out:
# 0.6803400637619553

# %%
mean_absolute_error(y_train,cnb.predict(X_train)) ,mean_absolute_error(y_test,cnb.predict(X_test))
# Out:
# (0.30835857378181625, 0.3196599362380446)

# %% [markdown]
# ### `Bernoulli Naive Bayes`

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
bnb = BernoulliNB()
bnb.fit(X_train, y_train)
bnb.score(X_test,y_test)
# Out:
# 0.8656748140276301

# %%
mean_absolute_error(y_train,bnb.predict(X_train)) ,mean_absolute_error(y_test,bnb.predict(X_test))
# Out:
# (0.13980551570221583, 0.1343251859723698)

# %% [markdown]
# **`Bernoulli Naive Bayes == Multinomial Naive Bayes`**

# %% [markdown]
# **Naive BayesNo  hyper parameter Found**
# <hr>

# %% [markdown]
# ## 3- K-Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
neigh = KNeighborsClassifier(n_neighbors=3)

# %%
neigh.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
neigh.score(X_test,y_test)
# Out:
# 0.8603613177470776

# %%
mean_absolute_error(y_train,neigh.predict(X_train)) ,mean_absolute_error(y_test,neigh.predict(X_test))
# Out:
# (0.08932461873638345, 0.13963868225292242)

# %%
print(classification_report(y_train,neigh.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95     16149
#            1       0.78      0.52      0.62      2670
#
#     accuracy                           0.91     18819
#    macro avg       0.85      0.75      0.79     18819
# weighted avg       0.90      0.91      0.90     18819

# %%
print(classification_report(y_test,neigh.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92      4063
#            1       0.48      0.34      0.40       642
#
#     accuracy                           0.86      4705
#    macro avg       0.69      0.64      0.66      4705
# weighted avg       0.84      0.86      0.85      4705

# %% [markdown]
# OOOHH `Nice` man this algorith is very efficency\
# lets do hyper parameter

# %% [markdown]
# ## KNN hyper pareameter

# %%
clf = [
#     KNeighborsClassifier(n_neighbors=3),
#     KNeighborsClassifier(n_neighbors=2,weights='distance'),
#     KNeighborsClassifier(n_neighbors=3,algorithm='kd_tree'),
#     KNeighborsClassifier(n_neighbors=3,algorithm='ball_tree'),
#     KNeighborsClassifier(n_neighbors=2,algorithm='brute'),
#     KNeighborsClassifier(n_neighbors=3,algorithm='brute'),
#     KNeighborsClassifier(n_neighbors=4,algorithm='brute'),
    KNeighborsClassifier(n_neighbors=4,algorithm='brute',p=1),
    KNeighborsClassifier(n_neighbors=5,algorithm='brute',p=1), #five neiphors
    KNeighborsClassifier(n_neighbors=6,algorithm='brute',p=1),
    KNeighborsClassifier(n_neighbors=7,algorithm='brute',p=1)
#     KNeighborsClassifier(n_neighbors=4,algorithm='brute',metric='precomputed')
    
    ]
clf_columns = []
clf_compare = pd.DataFrame(columns = clf_columns)

row_index = 0
for alg in clf:
        
    predicted = alg.fit(X_train, y_train).predict(X_test)
    fp, tp, th = roc_curve(y_test, predicted)
    clf_name = alg.__class__.__name__
    clf_compare.loc[row_index, 'Train Accuracy'] = round(alg.score(X_train, y_train), 5)
    clf_compare.loc[row_index, 'Test Accuracy'] = round(alg.score(X_test, y_test), 5)
    clf_compare.loc[row_index, 'Precission'] = round(precision_score(y_test, predicted),5)
    clf_compare.loc[row_index, 'Recall'] = round(recall_score(y_test, predicted),5)
    clf_compare.loc[row_index, 'AUC'] = round(auc(fp, tp),5)

    row_index+=1
    
clf_compare.sort_values(by = ['Test Accuracy'], ascending = False, inplace = True)    
clf_compare
# Out:
#    Train Accuracy  Test Accuracy  Precission   Recall      AUC
# 2         0.89043        0.88055     0.66667  0.24922  0.61477
# 0         0.89558        0.87694     0.62651  0.24299  0.61005
# 3         0.89271        0.87694     0.59517  0.30685  0.63694
# 1         0.89787        0.87269     0.55858  0.31931  0.63972

# %% [markdown]
# the  `KNeighborsClassifier(n_neighbors=6,algorithm='brute',p=1)` is most optomize model

# %%
neigh = KNeighborsClassifier(n_neighbors=6,algorithm='brute',p=1)

# %%
neigh.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='brute', n_neighbors=6, p=1)

# %%
neigh.score(X_test,y_test)
# Out:
# 0.8805526036131774

# %%
mean_absolute_error(y_train,neigh.predict(X_train)) ,mean_absolute_error(y_test,neigh.predict(X_test))
# Out:
# (0.10957011530899623, 0.11944739638682253)

# %%
wondodrfull lets make a predict with it

# %%
neigh = KNeighborsClassifier(n_neighbors=4,algorithm='brute',p=1)
neigh.fit(X_train, y_train)
neigh.score(X_test,y_test)
# Out:
# 0.8769394261424017

# %%
mean_absolute_error(y_train,neigh.predict(X_train)) ,mean_absolute_error(y_test,neigh.predict(X_test))
# Out:
# (0.10441575003985334, 0.1230605738575983)

# %%
# data = {'unique_id':td['uniqueid'] +' x ' + td['country'],
#        'bank_account':pred}

# %%
neigh.predict(test_label_encode).info()
# Out:
# array([1, 1, 0, ..., 0, 0, 0])

# %%
# data = {'unique_id':td['uniqueid'] +' x ' + td['country'],
#        'bank_account':neigh.predict(test_label_encode)}

# third_submition = pd.DataFrame(data,index=None)

# third_submition.to_csv('third_submition3.csv',index=False)

# %% [markdown]
# ## 3- Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(X_train,y_train)
dtc.score(X_test,y_test)
# Out:
# 0.836769394261424

# %%
print(classification_report(y_test,dtc.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91      4063
#            1       0.40      0.41      0.40       642
#
#     accuracy                           0.84      4705
#    macro avg       0.65      0.66      0.66      4705
# weighted avg       0.84      0.84      0.84      4705

# %%
mean_absolute_error(y_train,dtc.predict(X_train)) ,mean_absolute_error(y_test,dtc.predict(X_test))
# Out:
# (0.0196078431372549, 0.16323060573857598)

# %% [markdown]
# ## DT hyper pareameter

# %%
clf = [
    DecisionTreeClassifier(),
    DecisionTreeClassifier(random_state=42, max_depth=100),
    DecisionTreeClassifier(random_state=42,max_features='auto',max_depth=1000),
    DecisionTreeClassifier(random_state=42,max_features='auto',min_samples_leaf=2),
    DecisionTreeClassifier(random_state=42,max_features='auto',min_samples_leaf=2,max_depth=1000),
    DecisionTreeClassifier(random_state=42,max_features='auto',min_samples_leaf=3,max_depth=1000),
    DecisionTreeClassifier(random_state=42,max_features='auto',min_samples_leaf=4,max_depth=1000),
    DecisionTreeClassifier(random_state=42,max_features='auto',min_samples_leaf=5,max_depth=1000),
    DecisionTreeClassifier(random_state=42,max_features='auto',min_samples_leaf=5,max_depth=1000,max_leaf_nodes=6),
#     DecisionTreeClassifier(random_state=42,max_features='auto',min_samples_leaf=5,max_depth=1000,max_leaf_nodes=6)
#     DecisionTreeClassifier(random_state=42,max_features='auto',min_samples_leaf=5,max_depth=1000),
#     DecisionTreeClassifier(random_state=42,max_features='auto',min_samples_leaf=5,max_depth=1000,min_impurity_decrease=.002)
    
    ]
clf_columns = []
clf_compare = pd.DataFrame(columns = clf_columns)

row_index = 0
for alg in clf:
        
    predicted = alg.fit(X_train, y_train).predict(X_test)
    fp, tp, th = roc_curve(y_test, predicted)
    clf_name = alg.__class__.__name__
    clf_compare.loc[row_index, 'Train Accuracy'] = round(alg.score(X_train, y_train), 5)
    clf_compare.loc[row_index, 'Test Accuracy'] = round(alg.score(X_test, y_test), 5)
    clf_compare.loc[row_index, 'Precission'] = round(precision_score(y_test, predicted),5)
    clf_compare.loc[row_index, 'Recall'] = round(recall_score(y_test, predicted),5)
    clf_compare.loc[row_index, 'AUC'] = round(auc(fp, tp),5)
    clf_compare.loc[row_index, 'MEA'] = round(mean_absolute_error(y_test,alg.predict(X_test)),5)
#     clf_compare.loc[row_index, 'MEA2'] = round(mean_absolute_error(y_test,predicted),5)
    
    row_index+=1
    
clf_compare.sort_values(by = ['Test Accuracy'], ascending = False, inplace = True)    
clf_compare
# Out:
#    Train Accuracy  Test Accuracy  Precission   Recall      AUC      MEA
# 8         0.87608        0.88374     0.68924  0.26947  0.62514  0.11626
# 7         0.89930        0.88204     0.62117  0.34735  0.65694  0.11796
# 6         0.90164        0.87970     0.60053  0.35358  0.65821  0.12030
# 5         0.91014        0.87609     0.57074  0.37072  0.66333  0.12391
# 3         0.92157        0.87354     0.55188  0.38941  0.66972  0.12646
# 4         0.92157        0.87354     0.55188  0.38941  0.66972  0.12646
# 2         0.98039        0.84995     0.44904  0.43925  0.67705  0.15005
# 1         0.98039        0.83613     0.40092  0.40654  0.65528  0.16387
# 0         0.98039        0.83443     0.39637  0.40810  0.65495  0.16557

# %%
dtc = DecisionTreeClassifier(random_state=42,max_features='auto',min_samples_leaf=5,max_depth=1000,max_leaf_nodes=6)
dtc.fit(X_train,y_train)
dtc.score(X_test,y_test)
# Out:
# 0.8837407013815091

# %%
mean_absolute_error(y_train,dtc.predict(X_train)) ,mean_absolute_error(y_test,dtc.predict(X_test))
# Out:
# (0.12391731760454859, 0.11625929861849096)

# %%
dtc = DecisionTreeClassifier(random_state=42,max_features='auto',max_depth=1000)
dtc.fit(X_train,y_train)
dtc.score(X_test,y_test) , mean_absolute_error(y_train,dtc.predict(X_train)) ,mean_absolute_error(y_test,dtc.predict(X_test))
# Out:
# (0.8499468650371945, 0.0196078431372549, 0.15005313496280553)

# %%
dtc = DecisionTreeClassifier(random_state=42,max_features='auto',min_samples_leaf=6,max_depth=1000,max_leaf_nodes=9)
dtc.fit(X_train,y_train)
dtc.score(X_test,y_test), mean_absolute_error(y_train,dtc.predict(X_train)) ,mean_absolute_error(y_test,dtc.predict(X_test))
# Out:
# (0.8837407013815091, 0.12391731760454859, 0.11625929861849096)

# %% [markdown]
# ooh yes!!

# %% [markdown]
# Les See Advanced Algorithm Now!

# %% [markdown]
# # Advance Algorithm (Ensemble Learning)

# %% [markdown]
# ## 1 -Random Forests.
# ## 2 -LightGBM.
# ## 3 -XGBoost.
# <hr>

# %% [markdown]
# ## 1- Random Forests Classifiers

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(max_depth=2, random_state=42)
rfc.fit(X_train, y_train)
rfc.score(X_test,y_test) , mean_absolute_error(y_train,rfc.predict(X_train)) ,mean_absolute_error(y_test,rfc.predict(X_test))
# Out:
# (0.8635494155154091, 0.14187788936712897, 0.13645058448459085)

# %% [markdown]
# ## Random Forest hyper parameter

# %%
clf = [
#     RandomForestClassifier(max_depth=2, random_state=42),
#     RandomForestClassifier(max_depth=2, random_state=42,n_estimators=1000),
#     RandomForestClassifier(max_depth=3, random_state=42),
#     RandomForestClassifier(max_depth=4, random_state=42),
#     RandomForestClassifier(max_depth=5, random_state=42),
    
#     RandomForestClassifier(max_depth=10, random_state=42),
#     RandomForestClassifier(max_depth=12, random_state=42),
#     RandomForestClassifier(max_depth=14, random_state=42),
#     RandomForestClassifier(max_depth=16, random_state=42),
    
    RandomForestClassifier(random_state=42,max_depth=8,),
    RandomForestClassifier(random_state=42,max_depth=8,n_jobs=-1),
    RandomForestClassifier(random_state=42,max_depth=8,max_features='auto',min_samples_leaf=2),
    ]
clf_columns = []
clf_compare = pd.DataFrame(columns = clf_columns)

row_index = 0
for alg in clf:
        
    predicted = alg.fit(X_train, y_train).predict(X_test)
    fp, tp, th = roc_curve(y_test, predicted)
    clf_name = alg.__class__.__name__
    clf_compare.loc[row_index, 'Train Accuracy'] = round(alg.score(X_train, y_train), 5)
    clf_compare.loc[row_index, 'Test Accuracy'] = round(alg.score(X_test, y_test), 5)
    clf_compare.loc[row_index, 'Precission'] = round(precision_score(y_test, predicted),5)
    clf_compare.loc[row_index, 'Recall'] = round(recall_score(y_test, predicted),5)
    clf_compare.loc[row_index, 'AUC'] = round(auc(fp, tp),5)
#     clf_compare.loc[row_index, 'MEA'] = round(mean_absolute_error(y_test,alg.predict(X_test)),5)
    clf_compare.loc[row_index, 'MEA'] = round(mean_absolute_error(y_test,predicted),5)
    
    row_index+=1
    
clf_compare.sort_values(by = ['Test Accuracy'], ascending = False, inplace = True)    
clf_compare
# Out:
#    Train Accuracy  Test Accuracy  Precission   Recall      AUC      MEA
# 0         0.89256        0.89139     0.75686  0.30062  0.64268  0.10861
# 1         0.89256        0.89139     0.75686  0.30062  0.64268  0.10861
# 2         0.89171        0.89012     0.75100  0.29128  0.63801  0.10988

# %%
rfc = RandomForestClassifier(random_state=42,max_depth=8)
rfc.fit(X_train,y_train)
rfc.score(X_test,y_test) , mean_absolute_error(y_train,rfc.predict(X_train)) ,mean_absolute_error(y_test,rfc.predict(X_test))
# Out:
# (0.8913921360255048, 0.10744460385780329, 0.10860786397449522)

# %%
# data = {'unique_id':td['uniqueid'] +' x ' + td['country'],
#        'bank_account':rfc.predict(test_label_encode)}

# fourn_submition = pd.DataFrame(data,index=None)

# fourn_submition.to_csv('four_submition.csv',index=False)

# %% [markdown]
# ## 2- LightGBM

# %%
import lightgbm as ltb

# %%
model = ltb.LGBMClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# LGBMClassifier()

# %%
model.score(X_test,y_test)
# Out:
# 0.8928799149840595

# %%
mean_absolute_error(y_train,model.predict(X_train)) ,mean_absolute_error(y_test,model.predict(X_test))
# Out:
# (0.09857059354907274, 0.10712008501594049)

# %%
print(classification_report(y_test,model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      4063
#            1       0.69      0.39      0.50       642
#
#     accuracy                           0.89      4705
#    macro avg       0.80      0.68      0.72      4705
# weighted avg       0.88      0.89      0.88      4705

# %% [markdown]
# ## LightGBM hyper parameter

# %%
clf = [
    ltb.LGBMClassifier(),
    ltb.LGBMClassifier(num_leaves=20),
    ltb.LGBMClassifier(num_leaves=20,max_depth=12),
    ltb.LGBMClassifier(num_leaves=20)
    
]
clf_columns = []
clf_compare = pd.DataFrame(columns = clf_columns)

row_index = 0
for alg in clf:
        
    predicted = alg.fit(X_train, y_train).predict(X_test)
    fp, tp, th = roc_curve(y_test, predicted)
    clf_name = alg.__class__.__name__
    clf_compare.loc[row_index, 'Train Accuracy'] = round(alg.score(X_train, y_train), 5)
    clf_compare.loc[row_index, 'Test Accuracy'] = round(alg.score(X_test, y_test), 5)
    clf_compare.loc[row_index, 'Precission'] = round(precision_score(y_test, predicted),5)
    clf_compare.loc[row_index, 'Recall'] = round(recall_score(y_test, predicted),5)
    clf_compare.loc[row_index, 'AUC'] = round(auc(fp, tp),5)
    clf_compare.loc[row_index, 'MEA'] = round(mean_absolute_error(y_test,predicted),5)
    
    row_index+=1
    
clf_compare.sort_values(by = ['Test Accuracy'], ascending = False, inplace = True)    
clf_compare
# Out:
#    Train Accuracy  Test Accuracy  Precission   Recall      AUC      MEA
# 1         0.89558        0.89352     0.70085  0.38318  0.67867  0.10648
# 2         0.89558        0.89352     0.70085  0.38318  0.67867  0.10648
# 3         0.89558        0.89352     0.70085  0.38318  0.67867  0.10648
# 0         0.90143        0.89288     0.69061  0.38941  0.68092  0.10712

# %%
# data = {'unique_id':td['uniqueid'] +' x ' + td['country'],
#        'bank_account':clf[1].predict(test_label_encode)}

# five_submition = pd.DataFrame(data,index=None)

# five_submition.to_csv('five_submition.csv',index=False)

# %% [markdown]
# ## 3- XGBoost

# %%
from xgboost import XGBClassifier

# %%
from sklearn.metrics import accuracy_score

# %%
xgb_classifier = xgb.XGBClassifier()

# %%
xgb_classifier.fit(X_train,y_train)
# Out:
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Users\ali\miniconda3\envs\tf\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ...

# %%
xgb_classifier.fit(X_train,y_train)
# Out:
# [15:58:43] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=4,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
xgb_classifier.score(X_test,y_test)
# Out:
# 0.8905419766206164

# %%
mean_absolute_error(y_train,xgb_classifier.predict(X_train)) ,mean_absolute_error(y_test,xgb_classifier.predict(X_test))
# Out:
# (0.08167277751208885, 0.10945802337938364)

# %% [markdown]
# lets

# %% [markdown]
# ## XGBoost hyper parameter

# %%
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe
import warnings
warnings.filterwarnings('ignore')

# %%
space={'max_depth': hp.quniform("max_depth", 3, 18, 1),
        'gamma': hp.uniform ('gamma', 1,9),
        'reg_alpha' : hp.quniform('reg_alpha', 40,180,1),
        'reg_lambda' : hp.uniform('reg_lambda', 0,1),
        'colsample_bytree' : hp.uniform('colsample_bytree', 0.5,1),
        'min_child_weight' : hp.quniform('min_child_weight', 0, 10, 1),
        'n_estimators': 180,
        'seed': 0
    }

# %%
import xgboost as xgb

# %%
def objective(space):
    clf=xgb.XGBClassifier(
                    n_estimators =space['n_estimators'], max_depth = int(space['max_depth']), gamma = space['gamma'],
                    reg_alpha = int(space['reg_alpha']),min_child_weight=int(space['min_child_weight']),
                    colsample_bytree=int(space['colsample_bytree']))
    
    evaluation = [( X_train, y_train), ( X_test, y_test)]
    
    clf.fit(X_train, y_train,
            eval_set=evaluation, eval_metric="auc",
            early_stopping_rounds=10,verbose=False)
    

    pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, pred>0.5)
    print ("SCORE:", accuracy)
    return {'loss': -accuracy, 'status': STATUS_OK }

# %%
trials = Trials()

# %%
best_hyperparams = fmin(fn = objective,
                        space = space,
                        algo = tpe.suggest,
                        max_evals = 100,
                        trials = trials)
# Out:
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8720510095642933
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8750265674814027
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8716259298618491
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8722635494155154
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8739638682252923
# SCORE:
# 0.8718384697130712
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8635494155154091
# SCORE:
# 0.8718384697130712
# SCORE:
# 0.8635494155154091
# SCORE:
# ...

# %%
print("The best hyperparameters are : ","\n")
print(best_hyperparams)
# Out:
# The best hyperparameters are :
#
# {'colsample_bytree': 0.7383305918194502, 'gamma': 3.976449755704076, 'max_depth': 5.0, 'min_child_weight': 5.0, 'reg_alpha': 98.0, 'reg_lambda': 0.670431796868164}

# %%
best_xgb = xgb.XGBClassifier(colsample_by_tree=9691720381808693,
                         gamma =  6.26691050972726,
                         max_depth =  7,
                          min_child_weight =  3,
                          reg_alpha =  47,
                          reg_lambda = 0.7890195246409742
                         )

# %%
best_xgb.fit(X_train,y_train)
# Out:
# [16:18:19] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "colsample_by_tree" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [16:18:19] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree',
#               colsample_by_tree=9691720381808693, colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
# ...

# %%
best_xgb.score(X_test,y_test)
# Out:
# 0.8890541976620616

# %%
mean_absolute_error(y_train,best_xgb.predict(X_train)) ,mean_absolute_error(y_test,best_xgb.predict(X_test))
# Out:
# (0.11568096073117594, 0.11094580233793837)

# %% [markdown]
# at last this I can do
